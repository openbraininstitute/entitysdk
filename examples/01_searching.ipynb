# %%
import os

from rich import print as rprint

from entitysdk.client import Client
from entitysdk.common import ProjectContext
from entitysdk.models import (
    MTypeClass,
    Organization,
    Person,
    CellMorphology,
    Role,
    Species,
    Strain,
)

entitycore_api_url = "http://127.0.0.1:8000"
project_context = ProjectContext(
    virtual_lab_id="a98b7abc-fc46-4700-9e3d-37137812c730",
    project_id="0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6",
)
token = os.getenv("ACCESS_TOKEN", "XXX")
client = Client(api_url=entitycore_api_url, project_context=project_context, token_manager=token)


# uncomment for staging
# from obi_auth import get_token

# token = get_token(environment="staging")
# client = Client(environment="staging")

# %% [markdown]
# ## List all species

# %%
all_species = client.search_entity(entity_type=Species).all()

# %%
rprint(len(all_species))
rprint(all_species)
# Out:
# 9
# [
#     Species(
#         id=UUID('d322a735-3ead-4efe-840e-2b4fda9c025a'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715312, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715311, tzinfo=TzInfo(UTC)),
#         name='Aquarana catesbeiana',
#         taxonomy_id='NCBITaxon:8400'
#     ),
#     Species(
#         id=UUID('9779ac1f-45e9-4d32-8c85-5fdfa7251af0'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715308, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715307, tzinfo=TzInfo(UTC)),
#         name='Cricetulus griseus',
#         taxonomy_id='NCBITaxon:10029'
#     ),
#     Species(
#         id=UUID('ea748db9-e020-407a-aeb6-db2c3a038a70'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715309, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715308, tzinfo=TzInfo(UTC)),
#         name='Felis catus',
#         taxonomy_id='NCBITaxon:9685'
#     ),
#     Species(
#         id=UUID('ff3fe32a-30ff-44ee-90a7-bd04e85bfcdd'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715305, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715304, tzinfo=TzInfo(UTC)),
#         name='Homo sapiens',
#         taxonomy_id='NCBITaxon:9606'
#     ),
#     Species(
#         id=UUID('0f756132-e16d-4e72-b18e-859835e1f291'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715313, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715312, tzinfo=TzInfo(UTC)),
#         name='Hybrid human-mouse',
#         taxonomy_id='NA'
#     ),
#     Species(
#         id=UUID('22f1a831-85b9-4f5f-811e-60de1b343f52'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715310, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715310, tzinfo=TzInfo(UTC)),
#         name='Loligo pealeii',
#         taxonomy_id='NCBITaxon:6619'
#     ),
#     Species(
#         id=UUID('b7ad4cca-4ac2-4095-9781-37fb68fe9ca1'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 183929, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 183929, tzinfo=TzInfo(UTC)),
#         name='Mus musculus',
#         taxonomy_id='NCBITaxon:10090'
#     ),
#     Species(
#         id=UUID('3b1c2a25-b4fb-468d-98d2-d2d431ac8b4a'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 11, 57, 148444, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 11, 57, 148444, tzinfo=TzInfo(UTC)),
#         name='Rattus norvegicus',
#         taxonomy_id='NCBITaxon:10116'
#     ),
#     Species(
#         id=UUID('930cdbd3-0f0a-42a8-9b2d-19a2beaa14a7'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715306, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715306, tzinfo=TzInfo(UTC)),
#         name='Xenopus laevis',
#         taxonomy_id='NCBITaxon:8355'
#     )
# ]

# %% [markdown]
# ## List all strains

# %%
all_strains = client.search_entity(entity_type=Strain).all()

# %%
rprint(len(all_strains))
rprint(all_strains[:2])
# Out:
# 30
# [
#     Strain(
#         id=UUID('bf801e25-b43f-4b1e-8ba0-b18951e33dd6'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 11, 3, 655779, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 11, 3, 655779, tzinfo=TzInfo(UTC)),
#         name='C57BL/6J',
#         taxonomy_id='http://www.ebi.ac.uk/efo/EFO_0000606',
#         species_id=UUID('b7ad4cca-4ac2-4095-9781-37fb68fe9ca1')
#     ),
#     Strain(
#         id=UUID('9bb29bce-6e49-4b9f-907f-241cfceb7815'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 11, 3, 755012, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 11, 3, 755012, tzinfo=TzInfo(UTC)),
#         name='C57BL/6N',
#         taxonomy_id='https://phenome.jax.org/strains/138',
#         species_id=UUID('b7ad4cca-4ac2-4095-9781-37fb68fe9ca1')
#     )
# ]

# %% [markdown]
# ## List all roles

# %%
all_roles = client.search_entity(entity_type=Role).all()

# %%
rprint(len(all_roles))
rprint(all_roles[:2])
# Out:
# 9
# [
#     Role(
#         id=UUID('5db149c5-6bcf-42df-aea5-f075cac49ff2'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 12, 40, 177373, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 12, 40, 177373, tzinfo=TzInfo(UTC)),
#         name='creator role',
#         role_id='http://purl.obolibrary.org/obo/CRO_0000107'
#     ),
#     Role(
#         id=UUID('385f66ed-a460-4ed7-8fe4-5f202c3fd8be'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 11, 57, 152775, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 11, 57, 152775, tzinfo=TzInfo(UTC)),
#         name='data collection role',
#         role_id='obo:CRO_0000036'
#     )
# ]

# %% [markdown]
# ## List all users

# %%
all_users = client.search_entity(entity_type=Person).all()

# %%
rprint(len(all_users))
rprint(all_users[:2])
# Out:
# 499
# [
#     Person(
#         id=UUID('ab00247a-775d-4367-b122-693edc2aecbe'),
#         update_date=datetime.datetime(2025, 9, 19, 8, 2, 53, 819033, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 9, 19, 8, 2, 53, 819033, tzinfo=TzInfo(UTC)),
#         type='person',
#         pref_label='Admin User',
#         given_name=None,
#         family_name=None
#     ),
#     Person(
#         id=UUID('0227eeb7-b9d7-401f-9769-da05d205bbfc'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 49, 931702, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715289, tzinfo=TzInfo(UTC)),
#         type='person',
#         pref_label='Chandrashekarj Jayaram',
#         given_name='Chandrashekarj',
#         family_name='Jayaram'
#     )
# ]

# %% [markdown]
# ## List all organizations

# %%
all_orgs = client.search_entity(entity_type=Organization).all()

# %%
rprint(len(all_orgs))
rprint(all_orgs[:2])
# Out:
# 26
# [
#     Organization(
#         id=UUID('c8c69069-134b-4cd3-a1cf-4f589f8e4ce0'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 49, 915412, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715286, tzinfo=TzInfo(UTC)),
#         type='organization',
#         pref_label='Yale School of Medicine',
#         alternative_name=''
#     ),
#     Organization(
#         id=UUID('af29d115-ef24-4d62-9dd9-61e6830b54fa'),
#         update_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715283, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 6, 27, 11, 10, 28, 715283, tzinfo=TzInfo(UTC)),
#         type='organization',
#         pref_label='NeuroMorpho.Org (RRID:SCR_002145)',
#         alternative_name=''
#     )
# ]

# %% [markdown]
# ## List all mtypes

# %%
all_mtypes = client.search_entity(entity_type=MTypeClass).all()

# %%
rprint(len(all_mtypes))
rprint(all_mtypes[:2])
# Out:
# 708
# [
#     MTypeClass(
#         id=UUID('a88f4b03-f09c-4a85-ae3d-da7d4c985c19'),
#         update_date=datetime.datetime(2024, 11, 22, 11, 20, 32, 647067, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2023, 5, 30, 16, 44, 11, 344000, tzinfo=TzInfo(UTC)),
#         pref_label='A_BC',
#         definition='Basket cell in amygdala',
#         alt_label=''
#     ),
#     MTypeClass(
#         id=UUID('434b81a7-419d-4434-a516-1925d29cc9cf'),
#         update_date=datetime.datetime(2024, 11, 22, 11, 17, 20, 133849, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2023, 5, 30, 16, 44, 12, 443000, tzinfo=TzInfo(UTC)),
#         pref_label='A_BFP',
#         definition='Basal forebrain-projecting cell in amygdala',
#         alt_label=''
#     )
# ]

# %% [markdown]
# ## List N morphologies

# %%
morphs = client.search_entity(entity_type=CellMorphology, limit=10).all()

# %%
rprint(len(morphs))
rprint(morphs[:2])
# Out:
# 10
# [
#     CellMorphology(
#         assets=[
#             Asset(
#                 id=UUID('5bb8dd5c-3009-40d0-86d9-9420f8fa7ba5'),
#                 update_date=None,
#                 creation_date=None,
#                 path='NMO_159989.swc',
#                 full_path='public/a98b7abc-fc46-4700-9e3d-37137812c730/0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6/assets/
# reconstruction_morphology/8ad9fa02-d206-4578-95c5-abf8fe930a91/NMO_159989.swc',
#                 is_directory=False,
#                 content_type=<ContentType.application_swc: 'application/swc'>,
#                 size=204645,
#                 sha256_digest='35c714c62d11211304ef60c6a1ea293a72005555ba79bc9afdd4c269037294be',
#                 status=<AssetStatus.created: 'created'>,
#                 meta={},
#                 label=<AssetLabel.morphology: 'morphology'>
#             )
#         ],
#         id=UUID('8ad9fa02-d206-4578-95c5-abf8fe930a91'),
#         update_date=datetime.datetime(2025, 4, 1, 15, 50, 29, 929440, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 4, 1, 15, 43, 52, 330389, tzinfo=TzInfo(UTC)),
#         name='NMO_159989',
#         description='Morphological reconstruction of a pyramidal cell from the human temporal cortex. Part of the
# dataset from Moradi et al., 2021 (https://doi.org/10.1038/s41467-021-22741-9)',
#         type=<EntityType.cell_morphology: 'cell_morphology'>,
#         created_by=Person(
#             id=UUID('59cc60b1-7604-44b4-a736-95c3e652c71a'),
#             update_date=None,
#             creation_date=None,
#             type='person',
#             pref_label='service-account-obp-singlecell-uploader-sa service-account-obp-singlecell-uploader-sa',
#             given_name='service-account-obp-singlecell-uploader-sa',
#             family_name='service-account-obp-singlecell-uploader-sa'
#         ),
#         updated_by=Person(
#             id=UUID('59cc60b1-7604-44b4-a736-95c3e652c71a'),
#             update_date=None,
#             creation_date=None,
#             type='person',
#             pref_label='service-account-obp-singlecell-uploader-sa service-account-obp-singlecell-uploader-sa',
#             given_name='service-account-obp-singlecell-uploader-sa',
#             family_name='service-account-obp-singlecell-uploader-sa'
#         ),
#         authorized_public=True,
#         authorized_project_id=UUID('0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6'),
#         contributions=[
#             Contribution(
#                 id=UUID('8f3a2104-24ad-4e89-a5dd-fcff05f95013'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Person(
#                     id=UUID('0575665b-82f1-4080-acf4-0d8a6f092ec5'),
#                     update_date=None,
#                     creation_date=None,
#                     type='person',
#                     pref_label='Taufik Ali Valiante',
#                     given_name='Taufik Ali',
#                     family_name='Valiante'
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             ),
#             Contribution(
#                 id=UUID('752cf918-49fd-4d27-92df-f6ec220a750d'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Person(
#                     id=UUID('c02659fe-2e87-4415-8511-baeb198ababb'),
#                     update_date=None,
#                     creation_date=None,
#                     type='person',
#                     pref_label='Homeira Moradi Chameh',
#                     given_name='Homeira',
#                     family_name='Moradi Chameh'
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             ),
#             Contribution(
#                 id=UUID('ac06a04a-128c-4a06-a9f9-de7774670b0b'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Organization(
#                     id=UUID('bc1b00d9-2838-4766-af9b-6bf2d037fe2e'),
#                     update_date=None,
#                     creation_date=None,
#                     type='organization',
#                     pref_label='University Health Network, University of Toronto',
#                     alternative_name=''
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             )
#         ],
#         legacy_id=[
#             'https://bbp.epfl.ch/data/bbp/mmb-point-neuron-framework-model/c0a68180-21d4-4633-b740-9c8d685fdbeb'
#         ],
#         experiment_date=None,
#         contact_email=None,
#         subject=Subject(
#             assets=[],
#             id=UUID('1c71c68c-44a4-4972-955d-7e0f264425e3'),
#             update_date=None,
#             creation_date=None,
#             name='Generic Homo sapiens',
#             description='',
#             type=None,
#             created_by=None,
#             updated_by=None,
#             authorized_public=False,
#             authorized_project_id=None,
#             contributions=None,
#             legacy_id=None,
#             sex=<Sex.unknown: 'unknown'>,
#             weight=None,
#             age_value=None,
#             age_min=None,
#             age_max=None,
#             age_period=None,
#             species=Species(
#                 id=UUID('ff3fe32a-30ff-44ee-90a7-bd04e85bfcdd'),
#                 update_date=None,
#                 creation_date=None,
#                 name='Homo sapiens',
#                 taxonomy_id='NCBITaxon:9606'
#             ),
#             strain=None
#         ),
#         brain_region=BrainRegion(
#             id=UUID('e182532d-9864-4016-99a9-94a05c8f8d9a'),
#             update_date=datetime.datetime(2025, 6, 27, 11, 10, 27, 186088, tzinfo=TzInfo(UTC)),
#             creation_date=datetime.datetime(2025, 6, 27, 11, 10, 27, 186088, tzinfo=TzInfo(UTC)),
#             name='Temporal association areas, layer 5',
#             annotation_value=289,
#             acronym='TEa5',
#             parent_structure_id=UUID('9ea18ae9-e7c1-4d53-9229-4e6cc7d757d7'),
#             hierarchy_id=UUID('e3e70682-c209-4cac-a29f-6fbed82c07cd'),
#             color_hex_triplet='15B0B3'
#         ),
#         license=License(
#             id=UUID('ad8686db-3cdd-4e3f-bcbd-812380a9eba7'),
#             update_date=datetime.datetime(2024, 1, 16, 14, 51, 5, 847971, tzinfo=TzInfo(UTC)),
#             creation_date=datetime.datetime(2024, 1, 10, 15, 58, 46, 7611, tzinfo=TzInfo(UTC)),
#             name='https://creativecommons.org/licenses/by/4.0/',
#             description='Creative Commons Corporation ("Creative Commons") is not a law firm and does not provide
# legal services or legal advice. Distribution of Creative Commons public licenses does not create a lawyer-client or
# other relationship. Creative Commons makes its licenses and related information available on an "as-is" basis.
# Creative Commons gives no warranties regarding its licenses, any material licensed under their terms and
# conditions, or any related information. Creative Commons disclaims all liability for damages resulting from their
# use to the fullest extent possible.',
#             label='CC BY 4.0 Deed'
#         ),
#         published_in=None,
#         cell_morphology_protocol=None,
#         location=None,
#         mtypes=[
#             MTypeClass(
#                 id=UUID('0dfbb782-c879-48ca-b9e9-da5f559259b4'),
#                 update_date=datetime.datetime(2024, 11, 22, 11, 20, 49, 693171, tzinfo=TzInfo(UTC)),
#                 creation_date=datetime.datetime(2020, 9, 23, 9, 25, 28, 774000, tzinfo=TzInfo(UTC)),
#                 pref_label='Pyramidal Neuron',
#                 definition='A neuron with a pyramidal shaped soma and two distinct dendritic trees. The basal
# dendrites emerge from the base and the apical dendrites from the apex of the pyramidal cell body.',
#                 alt_label='Pyramidal neuron'
#             )
#         ]
#     ),
#     CellMorphology(
#         assets=[
#             Asset(
#                 id=UUID('90ac48c5-ebb3-4b2a-a63d-0938d8280302'),
#                 update_date=None,
#                 creation_date=None,
#                 path='NMO_194161.CNG.swc',
#                 full_path='public/a98b7abc-fc46-4700-9e3d-37137812c730/0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6/assets/
# reconstruction_morphology/d9b6bcb6-e14c-490a-b7ab-4b513805016c/NMO_194161.CNG.swc',
#                 is_directory=False,
#                 content_type=<ContentType.application_swc: 'application/swc'>,
#                 size=194749,
#                 sha256_digest='38642eb9b275d655b9932b1f4fe468c698a51724f60feda529ef0da2c9e96101',
#                 status=<AssetStatus.created: 'created'>,
#                 meta={},
#                 label=<AssetLabel.morphology: 'morphology'>
#             )
#         ],
#         id=UUID('d9b6bcb6-e14c-490a-b7ab-4b513805016c'),
#         update_date=datetime.datetime(2025, 4, 1, 15, 50, 29, 468821, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 4, 1, 15, 43, 6, 871920, tzinfo=TzInfo(UTC)),
#         name='NMO_194161',
#         description='Morphological reconstruction of a pyramidal cell from the human temporal cortex. Part of the
# dataset from Howard et al., 2022 (https://doi.org/10.1093/gigascience/giac108)',
#         type=<EntityType.cell_morphology: 'cell_morphology'>,
#         created_by=Person(
#             id=UUID('59cc60b1-7604-44b4-a736-95c3e652c71a'),
#             update_date=None,
#             creation_date=None,
#             type='person',
#             pref_label='service-account-obp-singlecell-uploader-sa service-account-obp-singlecell-uploader-sa',
#             given_name='service-account-obp-singlecell-uploader-sa',
#             family_name='service-account-obp-singlecell-uploader-sa'
#         ),
#         updated_by=Person(
#             id=UUID('59cc60b1-7604-44b4-a736-95c3e652c71a'),
#             update_date=None,
#             creation_date=None,
#             type='person',
#             pref_label='service-account-obp-singlecell-uploader-sa service-account-obp-singlecell-uploader-sa',
#             given_name='service-account-obp-singlecell-uploader-sa',
#             family_name='service-account-obp-singlecell-uploader-sa'
#         ),
#         authorized_public=True,
#         authorized_project_id=UUID('0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6'),
#         contributions=[
#             Contribution(
#                 id=UUID('7a8d0ee2-f289-421c-b028-e0a403b3e151'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Person(
#                     id=UUID('0575665b-82f1-4080-acf4-0d8a6f092ec5'),
#                     update_date=None,
#                     creation_date=None,
#                     type='person',
#                     pref_label='Taufik Ali Valiante',
#                     given_name='Taufik Ali',
#                     family_name='Valiante'
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             ),
#             Contribution(
#                 id=UUID('821a3cf7-36bc-40e4-8329-20fd87fae901'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Person(
#                     id=UUID('c02659fe-2e87-4415-8511-baeb198ababb'),
#                     update_date=None,
#                     creation_date=None,
#                     type='person',
#                     pref_label='Homeira Moradi Chameh',
#                     given_name='Homeira',
#                     family_name='Moradi Chameh'
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             ),
#             Contribution(
#                 id=UUID('1e58e96d-9d24-4e65-97c6-75eec08f4cd9'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Organization(
#                     id=UUID('bc1b00d9-2838-4766-af9b-6bf2d037fe2e'),
#                     update_date=None,
#                     creation_date=None,
#                     type='organization',
#                     pref_label='University Health Network, University of Toronto',
#                     alternative_name=''
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             )
#         ],
#         legacy_id=[
#             'https://bbp.epfl.ch/data/bbp/mmb-point-neuron-framework-model/de846af4-dd87-4eec-99d1-40e5c38ac8f9'
#         ],
#         experiment_date=None,
#         contact_email=None,
#         subject=Subject(
#             assets=[],
#             id=UUID('1c71c68c-44a4-4972-955d-7e0f264425e3'),
#             update_date=None,
#             creation_date=None,
#             name='Generic Homo sapiens',
#             description='',
#             type=None,
#             created_by=None,
#             updated_by=None,
#             authorized_public=False,
#             authorized_project_id=None,
#             contributions=None,
#             legacy_id=None,
#             sex=<Sex.unknown: 'unknown'>,
#             weight=None,
#             age_value=None,
#             age_min=None,
#             age_max=None,
#             age_period=None,
#             species=Species(
#                 id=UUID('ff3fe32a-30ff-44ee-90a7-bd04e85bfcdd'),
#                 update_date=None,
#                 creation_date=None,
#                 name='Homo sapiens',
#                 taxonomy_id='NCBITaxon:9606'
#             ),
#             strain=None
#         ),
#         brain_region=BrainRegion(
#             id=UUID('fe3aeb11-da80-43bb-a6fc-c59ac962efe0'),
#             update_date=datetime.datetime(2025, 6, 27, 11, 10, 27, 186088, tzinfo=TzInfo(UTC)),
#             creation_date=datetime.datetime(2025, 6, 27, 11, 10, 27, 186088, tzinfo=TzInfo(UTC)),
#             name='Temporal association areas, layer 2/3',
#             annotation_value=1127,
#             acronym='TEa2/3',
#             parent_structure_id=UUID('9ea18ae9-e7c1-4d53-9229-4e6cc7d757d7'),
#             hierarchy_id=UUID('e3e70682-c209-4cac-a29f-6fbed82c07cd'),
#             color_hex_triplet='15B0B3'
#         ),
#         license=License(
#             id=UUID('74b8c953-67f5-4e95-ac58-095274901328'),
#             update_date=datetime.datetime(2025, 5, 14, 8, 34, 16, 249488, tzinfo=TzInfo(UTC)),
#             creation_date=datetime.datetime(2025, 5, 14, 8, 34, 16, 249488, tzinfo=TzInfo(UTC)),
#             name='https://creativecommons.org/publicdomain/zero/1.0/',
#             description='Creative Commons Corporation ("Creative Commons") is not a law firm and does not provide
# legal services or legal advice. Distribution of Creative Commons public licenses does not create a lawyer-client or
# other relationship. Creative Commons makes its licenses and related information available on an "as-is" basis.
# Creative Commons gives no warranties regarding its licenses, any material licensed under their terms and
# conditions, or any related information. Creative Commons disclaims all liability for damages resulting from their
# use to the fullest extent possible.',
#             label='CC0 1.0 Deed'
#         ),
#         published_in=None,
#         cell_morphology_protocol=None,
#         location=None,
#         mtypes=[
#             MTypeClass(
#                 id=UUID('0dfbb782-c879-48ca-b9e9-da5f559259b4'),
#                 update_date=datetime.datetime(2024, 11, 22, 11, 20, 49, 693171, tzinfo=TzInfo(UTC)),
#                 creation_date=datetime.datetime(2020, 9, 23, 9, 25, 28, 774000, tzinfo=TzInfo(UTC)),
#                 pref_label='Pyramidal Neuron',
#                 definition='A neuron with a pyramidal shaped soma and two distinct dendritic trees. The basal
# dendrites emerge from the base and the apical dendrites from the apex of the pyramidal cell body.',
#                 alt_label='Pyramidal neuron'
#             )
#         ]
#     )
# ]

# %% [markdown]
# ## Find morphologies by mtype

# %%
morphs = client.search_entity(
    entity_type=CellMorphology, query={"mtype__pref_label": "SR_PC"}
).all()

# %%
rprint(len(morphs))
rprint(morphs[:2])
# Out:
# 1
# [
#     CellMorphology(
#         assets=[
#             Asset(
#                 id=UUID('8c73ebe9-fe8a-4621-bc83-1f4dfc9bf5df'),
#                 update_date=None,
#                 creation_date=None,
#                 path='mpg150211_A_idA.swc',
#                 full_path='public/a98b7abc-fc46-4700-9e3d-37137812c730/0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6/assets/
# reconstruction_morphology/3d150e36-2980-48ba-b654-0e057d33b8df/mpg150211_A_idA.swc',
#                 is_directory=False,
#                 content_type=<ContentType.application_swc: 'application/swc'>,
#                 size=561221,
#                 sha256_digest='8b850eface3e7b881db62c361dc5da62be008ca81501c406a59646bf7075c95b',
#                 status=<AssetStatus.created: 'created'>,
#                 meta={},
#                 label=<AssetLabel.morphology: 'morphology'>
#             ),
#             Asset(
#                 id=UUID('4f63feb5-ee64-489b-9af3-59f3654c769c'),
#                 update_date=None,
#                 creation_date=None,
#                 path='mpg150211_A_idA.ASC',
#                 full_path='public/a98b7abc-fc46-4700-9e3d-37137812c730/0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6/assets/
# reconstruction_morphology/3d150e36-2980-48ba-b654-0e057d33b8df/mpg150211_A_idA.ASC',
#                 is_directory=False,
#                 content_type=<ContentType.application_asc: 'application/asc'>,
#                 size=525332,
#                 sha256_digest='bf00878444539ead825f2d451cdf6f87072526f9a82c87de35fca5563ae5596b',
#                 status=<AssetStatus.created: 'created'>,
#                 meta={},
#                 label=<AssetLabel.morphology: 'morphology'>
#             )
#         ],
#         id=UUID('3d150e36-2980-48ba-b654-0e057d33b8df'),
#         update_date=datetime.datetime(2024, 10, 29, 13, 36, 30, 827776, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2024, 9, 10, 14, 25, 3, 707956, tzinfo=TzInfo(UTC)),
#         name='mpg150211_A_idA',
#         description="Neuronal morphology of excitatory neuron cell 'mpg150211_A_idA' in Field CA1, pyramidal layer
# of cell type SR_PC. A neuron that releases excitatory neurotransmitters. This neuron doesn't have axon, has a basal
# dendrite and apical dendrite.",
#         type=<EntityType.cell_morphology: 'cell_morphology'>,
#         created_by=Person(
#             id=UUID('bd143fa9-b714-410c-a65d-7435c1066932'),
#             update_date=None,
#             creation_date=None,
#             type='person',
#             pref_label='Christina Gonzalez',
#             given_name='Christina',
#             family_name='Gonzalez'
#         ),
#         updated_by=Person(
#             id=UUID('7f81375e-ecc1-4b63-8773-3e847d718d73'),
#             update_date=None,
#             creation_date=None,
#             type='person',
#             pref_label='service-account-bbp-dke-data-pipelines-sa service-account-bbp-dke-data-pipelines-sa',
#             given_name='service-account-bbp-dke-data-pipelines-sa',
#             family_name='service-account-bbp-dke-data-pipelines-sa'
#         ),
#         authorized_public=True,
#         authorized_project_id=UUID('0dbced5f-cc3d-488a-8c7f-cfb8ea039dc6'),
#         contributions=[
#             Contribution(
#                 id=UUID('393f86f7-647d-4766-9120-5566f965e773'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Person(
#                     id=UUID('cf4fbeb8-fd17-40fd-ae6d-43f2e53f82d5'),
#                     update_date=None,
#                     creation_date=None,
#                     type='person',
#                     pref_label='Maurizio Pezzoli Gonzalez',
#                     given_name='Maurizio',
#                     family_name='Pezzoli Gonzalez'
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             ),
#             Contribution(
#                 id=UUID('bb07d774-216d-47d7-9fd8-549f9c5375a3'),
#                 update_date=None,
#                 creation_date=None,
#                 agent=Organization(
#                     id=UUID('36b621f5-5d56-45a2-9b49-f36261142cc4'),
#                     update_date=None,
#                     creation_date=None,
#                     type='organization',
#                     pref_label='École Polytechnique Fédérale de Lausanne',
#                     alternative_name=''
#                 ),
#                 role=Role(
#                     id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                     update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(UTC)),
#                     name='unspecified',
#                     role_id='unspecified'
#                 ),
#                 entity=None
#             )
#         ],
#         legacy_id=['https://bbp.epfl.ch/data/public/morphologies/bc745a33-343b-4c7d-a4a1-d66779e1dd72'],
#         experiment_date=None,
#         contact_email=None,
#         subject=Subject(
#             assets=[],
#             id=UUID('9edb44c6-33b5-403b-8ab6-0890cfb12d07'),
#             update_date=None,
#             creation_date=None,
#             name='Generic Mus musculus',
#             description='',
#             type=None,
#             created_by=None,
#             updated_by=None,
#             authorized_public=False,
#             authorized_project_id=None,
#             contributions=None,
#             legacy_id=None,
#             sex=<Sex.unknown: 'unknown'>,
#             weight=None,
#             age_value=None,
#             age_min=None,
#             age_max=None,
#             age_period=None,
#             species=Species(
#                 id=UUID('b7ad4cca-4ac2-4095-9781-37fb68fe9ca1'),
#                 update_date=None,
#                 creation_date=None,
#                 name='Mus musculus',
#                 taxonomy_id='NCBITaxon:10090'
#             ),
#             strain=None
#         ),
#         brain_region=BrainRegion(
#             id=UUID('37b2c03e-0498-4bde-adf3-308efc3c8c87'),
#             update_date=datetime.datetime(2025, 6, 27, 11, 10, 27, 186088, tzinfo=TzInfo(UTC)),
#             creation_date=datetime.datetime(2025, 6, 27, 11, 10, 27, 186088, tzinfo=TzInfo(UTC)),
#             name='Field CA1, pyramidal layer',
#             annotation_value=407,
#             acronym='CA1sp',
#             parent_structure_id=UUID('b0ffdc9a-933b-4d5e-aa3d-9f0d57a92bdf'),
#             hierarchy_id=UUID('e3e70682-c209-4cac-a29f-6fbed82c07cd'),
#             color_hex_triplet='66A83D'
#         ),
#         license=None,
#         published_in=None,
#         cell_morphology_protocol=None,
#         location=None,
#         mtypes=[
#             MTypeClass(
#                 id=UUID('0cae0d41-56c7-4a1a-a88e-be82eb901890'),
#                 update_date=datetime.datetime(2024, 11, 22, 11, 10, 32, 32504, tzinfo=TzInfo(UTC)),
#                 creation_date=datetime.datetime(2020, 3, 16, 10, 34, 59, 651000, tzinfo=TzInfo(UTC)),
#                 pref_label='SR_PC',
#                 definition='',
#                 alt_label=''
#             )
#         ]
#     )
# ]
