# %%
import os

from rich import print as rprint

from entitysdk.client import Client
from entitysdk.common import ProjectContext
from entitysdk.models.morphology import (
    BrainLocation,
    BrainRegion,
    ReconstructionMorphology,
    Species,
    Strain,
)

# %% [markdown]
# ### Initialize the entitycore client

# %%
entitycore_api_url = "http://127.0.0.1:8000"
project_context = ProjectContext(
    virtual_lab_id="103d7868-147e-4f07-af0d-71d8568f575c",
    project_id="103d7868-147e-4f07-af0d-71d8568f575c",
)
client = Client(api_url=entitycore_api_url, project_context=project_context)
token = os.getenv("ACCESS_TOKEN", "XXX")

# %% [markdown]
# ### Create a morphology object

# %%
# No GET endpoint yet for species
species = Species(id=1, name="Mus musculus", taxonomy_id="NCBITaxon:10090")
strain = Strain(
    id=1,
    name="Cux2-CreERT2",
    taxonomy_id="http://bbp.epfl.ch/neurosciencegraph/ontologies/speciestaxonomy/RBS4I6tyfUBSDt1i0jXLpgN",
    species_id=1,
)
brain_location = BrainLocation(
    id=1,
    x=4101.52490234375,
    y=1173.8499755859375,
    z=4744.60009765625,
)
brain_region = BrainRegion(
    id=68,
    name="Frontal pole, layer 1",
    acronym="FRP1",
    children=[],
)

morphology = ReconstructionMorphology(
    name="my-morph",
    description="A morphology",
    species=species,
    strain=strain,
    brain_region=brain_region,
    brain_location=brain_location,
    legacy_id="temp",
)

# %% [markdown]
# ## Register it

# %%
registered = client.register(
    entity=morphology,
    token=token,
)
rprint(registered)
# Out:
# ReconstructionMorphology(
#     update_date=datetime.datetime(2025, 2, 25, 14, 38, 24, 989480, tzinfo=TzInfo(UTC)),
#     creation_date=datetime.datetime(2025, 2, 25, 14, 38, 24, 989480, tzinfo=TzInfo(UTC)),
#     authorized_public=False,
#     authorized_project_id='103d7868-147e-4f07-af0d-71d8568f575c',
#     id=8675,
#     name='my-morph',
#     description='A morphology',
#     pref_label=None,
#     species=Species(
#         update_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Mus musculus',
#         taxonomy_id='NCBITaxon:10090'
#     ),
#     strain=Strain(
#         update_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Cux2-CreERT2',
#         taxonomy_id='http://bbp.epfl.ch/neurosciencegraph/ontologies/speciestaxonomy/RBS4I6tyfUBSDt1i0jXLpgN',
#         species_id=1
#     ),
#     brain_region=BrainRegion(
#         update_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=68,
#         name='Frontal pole, layer 1',
#         acronym='FRP1',
#         children=[]
#     ),
#     brain_location=BrainLocation(
#         update_date=None,
#         creation_date=None,
#         authorized_public=None,
#         authorized_project_id=None,
#         id=None,
#         x=4101.52490234375,
#         y=1173.8499755859375,
#         z=4744.60009765625
#     ),
#     license=None,
#     legacy_id=None
# )

# %% [markdown]
# ## Retrieve it

# %%
fetched = client.get(entity_id=registered.id, entity_type=ReconstructionMorphology, token=token)
rprint(fetched)
# Out:
# ReconstructionMorphology(
#     update_date=datetime.datetime(2025, 2, 25, 14, 38, 24, 989480, tzinfo=TzInfo(UTC)),
#     creation_date=datetime.datetime(2025, 2, 25, 14, 38, 24, 989480, tzinfo=TzInfo(UTC)),
#     authorized_public=False,
#     authorized_project_id='103d7868-147e-4f07-af0d-71d8568f575c',
#     id=8675,
#     name='my-morph',
#     description='A morphology',
#     pref_label=None,
#     species=Species(
#         update_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Mus musculus',
#         taxonomy_id='NCBITaxon:10090'
#     ),
#     strain=Strain(
#         update_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Cux2-CreERT2',
#         taxonomy_id='http://bbp.epfl.ch/neurosciencegraph/ontologies/speciestaxonomy/RBS4I6tyfUBSDt1i0jXLpgN',
#         species_id=1
#     ),
#     brain_region=BrainRegion(
#         update_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=68,
#         name='Frontal pole, layer 1',
#         acronym='FRP1',
#         children=[]
#     ),
#     brain_location=BrainLocation(
#         update_date=None,
#         creation_date=None,
#         authorized_public=None,
#         authorized_project_id=None,
#         id=None,
#         x=4101.52490234375,
#         y=1173.8499755859375,
#         z=4744.60009765625
#     ),
#     license=None,
#     legacy_id=None
# )

# %% [markdown]
# ## Search it

# %%
hits = client.search(
    entity_type=ReconstructionMorphology,
    query={"name": "my-morph", "page": 1, "page_size": 2},
    token=token,
)
for hit in hits:
    rprint(hit)
# Out:
# ReconstructionMorphology(
#     update_date=datetime.datetime(2025, 2, 25, 14, 37, 28, 796628, tzinfo=TzInfo(UTC)),
#     creation_date=datetime.datetime(2025, 2, 25, 14, 37, 28, 796628, tzinfo=TzInfo(UTC)),
#     authorized_public=False,
#     authorized_project_id='103d7868-147e-4f07-af0d-71d8568f575c',
#     id=8673,
#     name='my-morph',
#     description='A morphology',
#     pref_label=None,
#     species=Species(
#         update_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Mus musculus',
#         taxonomy_id='NCBITaxon:10090'
#     ),
#     strain=Strain(
#         update_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Cux2-CreERT2',
#         taxonomy_id='http://bbp.epfl.ch/neurosciencegraph/ontologies/speciestaxonomy/RBS4I6tyfUBSDt1i0jXLpgN',
#         species_id=1
#     ),
#     brain_region=BrainRegion(
#         update_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=68,
#         name='Frontal pole, layer 1',
#         acronym='FRP1',
#         children=[]
#     ),
#     brain_location=BrainLocation(
#         update_date=None,
#         creation_date=None,
#         authorized_public=None,
#         authorized_project_id=None,
#         id=None,
#         x=4101.52490234375,
#         y=1173.8499755859375,
#         z=4744.60009765625
#     ),
#     license=None,
#     legacy_id=None
# )
# ReconstructionMorphology(
#     update_date=datetime.datetime(2025, 2, 25, 14, 36, 56, 655367, tzinfo=TzInfo(UTC)),
#     creation_date=datetime.datetime(2025, 2, 25, 14, 36, 56, 655367, tzinfo=TzInfo(UTC)),
#     authorized_public=False,
#     authorized_project_id='103d7868-147e-4f07-af0d-71d8568f575c',
#     id=8672,
#     name='my-morph',
#     description='A morphology',
#     pref_label=None,
#     species=Species(
#         update_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 42, 56, 228818, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Mus musculus',
#         taxonomy_id='NCBITaxon:10090'
#     ),
#     strain=Strain(
#         update_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 43, 15, 38669, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=1,
#         name='Cux2-CreERT2',
#         taxonomy_id='http://bbp.epfl.ch/neurosciencegraph/ontologies/speciestaxonomy/RBS4I6tyfUBSDt1i0jXLpgN',
#         species_id=1
#     ),
#     brain_region=BrainRegion(
#         update_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         creation_date=datetime.datetime(2025, 2, 20, 13, 36, 48, 879956, tzinfo=TzInfo(UTC)),
#         authorized_public=None,
#         authorized_project_id=None,
#         id=68,
#         name='Frontal pole, layer 1',
#         acronym='FRP1',
#         children=[]
#     ),
#     brain_location=BrainLocation(
#         update_date=None,
#         creation_date=None,
#         authorized_public=None,
#         authorized_project_id=None,
#         id=None,
#         x=4101.52490234375,
#         y=1173.8499755859375,
#         z=4744.60009765625
#     ),
#     license=None,
#     legacy_id=None
# )
